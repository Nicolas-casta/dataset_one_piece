# %% [markdown]
# <a href="https://colab.research.google.com/github/Nicolas-casta/dataset_one_piece/blob/main/one_piece_episodes_and_characters.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.gridspec import GridSpec

# %%
df = pd.read_csv('/content/One_Piece_Episode_wise_Summary_1-1130.csv')
print(f"Dataset cargada: {df.shape[0]:,} filas y {df.shape[1]} columnas")
# Out:
# Dataset cargada: 1,130 filas y 5 columnas

# %%
df.head()
# Out:
#    episode                                       episode_name  \
# 0        1  I'm Luffy! The Man Who Will Become the Pirate ...
# 1        2  The Great Swordsman Appears! Pirate Hunter Ror...
# 2        3  Morgan vs. Luffy! Who's This Mysterious Beauti...
# 3        4        Luffy's Past! The Red-Haired Shanks Appears
# 4        5  Fear, Mysterious Power! Pirate Clown Captain B...
#
#                 arc                                            summary  \
# 0  Romance Dawn Arc  Luffy is cast at sea in a barrel. Sailors on a...
# 1  Romance Dawn Arc  Luffy and Koby arrive at Shells Town, a town w...
# 2  Romance Dawn Arc  Luffy returns the katana to Zoro, who uses the...
# 3   Orange Town Arc  The burglar girl's dinghy is discovered by thr...
# 4   Orange Town Arc  The girl introduces herself as Nami, a thief t...
#
#                                character_appearances
# 0  ['Nami', 'Alvida', 'Koby', 'Heppoko', 'Peppoko...
# 1  ['Monkey D. Luffy', 'Koby', 'Roronoa Zoro', 'R...
# 2  ['Roronoa Zoro', 'Monkey D. Luffy', 'Morgan', ...
# 3  ['Tightrope Walking Funan Bros', 'Nami', 'Monk...
# 4  ['Nami', 'Superhuman Domingos', 'Pinky', 'Monk...
